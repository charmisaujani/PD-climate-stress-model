# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load data files
remind_file = '/content/Downscaled_REMIND-MAgPIE 3.2-4.6_data.xlsx'
nigem_file = '/content/NiGEM_data.xlsx'

# %%
# Load REMIND-MAgPIE data
remind_df = pd.read_excel(remind_file)

# Load NiGEM macroeconomic data
nigem_df = pd.read_excel(nigem_file)

# %%
print(remind_df.columns.tolist())
# Out:
# ['Model', 'Scenario', 'Region', 'Variable', 'Unit', '2020', '2021', '2022', '2023', '2024', '2025', '2026', '2027', '2028', '2029', '2030', '2031', '2032', '2033', '2034', '2035', '2036', '2037', '2038', '2039', '2040', '2041', '2042', '2043', '2044', '2045', '2046', '2047', '2048', '2049', '2050', '2051', '2052', '2053', '2054', '2055', '2056', '2057', '2058', '2059', '2060', '2061', '2062', '2063', '2064', '2065', '2066', '2067', '2068', '2069', '2070', '2071', '2072', '2073', '2074', '2075', '2076', '2077', '2078', '2079', '2080', '2081', '2082', '2083', '2084', '2085', '2086', '2087', '2088', '2089', '2090', '2091', '2092', '2093', '2094', '2095', '2096', '2097', '2098', '2099', '2100']

# %%
# Melt from wide to long format
remind_long = remind_df.melt(
    id_vars=['Model', 'Scenario', 'Region', 'Variable', 'Unit'],
    var_name='Year',
    value_name='Value'
)
nigem_long = nigem_df.melt(
    id_vars=['Model', 'Scenario', 'Region', 'Variable', 'Unit'],
    var_name='Year',
    value_name='Value'
)

# %%
nigem_long['Region'] = nigem_long['Region'].str.split('|').str[-1].str.strip()

# %%
nigem_long.head()
# Out:
#                                    Model            Scenario  Region  \
# 0  NiGEM NGFS v1.23.2[Climate Analytics]  Delayed transition  Africa
# 1  NiGEM NGFS v1.23.2[Climate Analytics]  Delayed transition  Africa
# 2  NiGEM NGFS v1.23.2[Climate Analytics]  Delayed transition  Africa
# 3  NiGEM NGFS v1.23.2[Climate Analytics]  Delayed transition  Africa
# 4  NiGEM NGFS v1.23.2[Climate Analytics]  Delayed transition  Africa
#
#                                    Variable  \
# 0  Gross Domestic Product (GDP)(cyclone-60)
# 1  Gross Domestic Product (GDP)(cyclone-65)
# 2  Gross Domestic Product (GDP)(cyclone-70)
# 3  Gross Domestic Product (GDP)(cyclone-75)
# 4  Gross Domestic Product (GDP)(cyclone-80)
#
#                                       Unit  Year     Value
# 0  % difference,  2017 PPP; local currency  2022 -1.120393
# 1  % difference,  2017 PPP; local currency  2022 -1.254201
# 2  % difference,  2017 PPP; local currency  2022 -1.664838
# 3  % difference,  2017 PPP; local currency  2022 -2.551989
# 4  % difference,  2017 PPP; local currency  2022 -4.044783

# %%
# Ensure year is numeric
remind_long['Year'] = remind_long['Year'].astype(int)
nigem_long['Year'] = nigem_long['Year'].astype(int)

# %%
# Define scenarios and region of interest
scenarios = ['Net Zero 2050', 'Delayed transition']
region = 'EU27'
region_n = 'Europe'

# %%
remind_filtered = remind_long[
    (remind_long['Scenario'].isin(scenarios)) &
    (remind_long['Region'] == region) &
    (remind_long['Variable'].isin(['Price|Carbon', 'Emissions|CO2|Energy']))
]

nigem_filtered = nigem_long[
    (nigem_long['Scenario'].isin(scenarios)) &
    (nigem_long['Variable'] == 'Gross Domestic Product (GDP)(transition)') &
    (nigem_long['Region'] == region_n)
]

# %%
# Pivot to get variable by year
remind_pivot = remind_filtered.pivot_table(
    index=['Scenario', 'Variable', 'Region'], columns='Year', values='Value'
)
nigem_pivot = nigem_filtered.pivot_table(
    index=['Scenario', 'Variable', 'Region'], columns='Year', values='Value'
)

# %%
remind_pivot
# Out:
# Year                                                   2020         2025  \
# Scenario           Variable             Region
# Delayed transition Emissions|CO2|Energy EU27    2586.508033  2079.258967
#                    Price|Carbon         EU27      27.693100    26.331267
# Net Zero 2050      Emissions|CO2|Energy EU27    2587.316167  1962.965967
#                    Price|Carbon         EU27      27.693100   195.603033
#
# Year                                                   2030         2035  \
# Scenario           Variable             Region
# Delayed transition Emissions|CO2|Energy EU27    1802.298700  1390.577500
#                    Price|Carbon         EU27      25.016500   252.757100
# Net Zero 2050      Emissions|CO2|Energy EU27    1164.898433   376.602733
#                    Price|Carbon         EU27     253.062333   397.792700
#
# Year                                                  2040        2045  \
# Scenario           Variable             Region
# Delayed transition Emissions|CO2|Energy EU27    350.859900 -141.372000
#                    Price|Carbon         EU27    418.201367  583.499033
# Net Zero 2050      Emissions|CO2|Energy EU27   -200.658533 -370.222700
#                    Price|Carbon         EU27    542.673900  687.485800
#
# Year                                                  2050       2055  \
# Scenario           Variable             Region
# Delayed transition Emissions|CO2|Energy EU27   -330.694767 -368.44245
#                    Price|Carbon         EU27    748.943433  738.65615
# Net Zero 2050      Emissions|CO2|Energy EU27   -439.713367 -433.80505
#                    Price|Carbon         EU27    832.367233  838.15085
#
# Year                                                2060       2065  \
# Scenario           Variable             Region
# Delayed transition Emissions|CO2|Energy EU27   -395.5893 -412.66015
#                    Price|Carbon         EU27    736.0478  725.44070
# Net Zero 2050      Emissions|CO2|Energy EU27   -431.7173 -387.89110
#                    Price|Carbon         EU27    868.5986  890.37225
#
# Year                                                 2070       2075  \
# Scenario           Variable             Region
# Delayed transition Emissions|CO2|Energy EU27   -429.71890 -388.35805
#                    Price|Carbon         EU27    714.83360  716.67670
# Net Zero 2050      Emissions|CO2|Energy EU27   -344.67235 -309.68310
#                    Price|Carbon         EU27    912.14585  946.52445
#
# Year                                                 2080        2085  \
# Scenario           Variable             Region
# Delayed transition Emissions|CO2|Energy EU27   -347.15640  -292.46945
#                    Price|Carbon         EU27    718.51975   716.74650
# Net Zero 2050      Emissions|CO2|Energy EU27   -276.94270  -286.30935
#                    Price|Carbon         EU27    980.90305  1014.29835
#
# Year                                                  2090        2095  \
# Scenario           Variable             Region
# Delayed transition Emissions|CO2|Energy EU27    -238.87655  -231.37815
#                    Price|Carbon         EU27     714.97320   714.89640
# Net Zero 2050      Emissions|CO2|Energy EU27    -297.91755  -308.72410
#                    Price|Carbon         EU27    1047.69365  1077.18745
#
# Year                                                  2100
# Scenario           Variable             Region
# Delayed transition Emissions|CO2|Energy EU27    -224.11150
#                    Price|Carbon         EU27     714.81965
# Net Zero 2050      Emissions|CO2|Energy EU27    -319.69270
#                    Price|Carbon         EU27    1106.68125

# %%
nigem_pivot
# Out:
# Year                                                                2022  \
# Scenario           Variable                                 Region
# Delayed transition Gross Domestic Product (GDP)(transition) Europe   0.0
# Net Zero 2050      Gross Domestic Product (GDP)(transition) Europe   0.0
#
# Year                                                                   2023  \
# Scenario           Variable                                 Region
# Delayed transition Gross Domestic Product (GDP)(transition) Europe  0.00000
# Net Zero 2050      Gross Domestic Product (GDP)(transition) Europe -0.07138
#
# Year                                                                   2024  \
# Scenario           Variable                                 Region
# Delayed transition Gross Domestic Product (GDP)(transition) Europe  0.00000
# Net Zero 2050      Gross Domestic Product (GDP)(transition) Europe -0.89116
#
# Year                                                                    2025  \
# Scenario           Variable                                 Region
# Delayed transition Gross Domestic Product (GDP)(transition) Europe  0.000000
# Net Zero 2050      Gross Domestic Product (GDP)(transition) Europe -1.079191
#
# Year                                                                    2026  \
# Scenario           Variable                                 Region
# Delayed transition Gross Domestic Product (GDP)(transition) Europe  0.000000
# Net Zero 2050      Gross Domestic Product (GDP)(transition) Europe -1.034871
#
# Year                                                                    2027  \
# Scenario           Variable                                 Region
# Delayed transition Gross Domestic Product (GDP)(transition) Europe  0.000000
# Net Zero 2050      Gross Domestic Product (GDP)(transition) Europe -0.913566
#
# Year                                                                    2028  \
# Scenario           Variable                                 Region
# Delayed transition Gross Domestic Product (GDP)(transition) Europe  0.000000
# Net Zero 2050      Gross Domestic Product (GDP)(transition) Europe -0.773101
#
# Year                                                                   2029  \
# Scenario           Variable                                 Region
# Delayed transition Gross Domestic Product (GDP)(transition) Europe  0.00000
# Net Zero 2050      Gross Domestic Product (GDP)(transition) Europe -0.62593
#
# Year                                                                    2030  \
# Scenario           Variable                                 Region
# Delayed transition Gross Domestic Product (GDP)(transition) Europe  0.000000
# Net Zero 2050      Gross Domestic Product (GDP)(transition) Europe -0.466276
#
# Year                                                                    2031  \
# Scenario           Variable                                 Region
# Delayed transition Gross Domestic Product (GDP)(transition) Europe -0.211104
# Net Zero 2050      Gross Domestic Product (GDP)(transition) Europe -0.378482
#
# Year                                                                ...  \
# Scenario           Variable                                 Region  ...
# Delayed transition Gross Domestic Product (GDP)(transition) Europe  ...
# Net Zero 2050      Gross Domestic Product (GDP)(transition) Europe  ...
#
# Year                                                                    2041  \
# Scenario           Variable                                 Region
# Delayed transition Gross Domestic Product (GDP)(transition) Europe -0.707438
# Net Zero 2050      Gross Domestic Product (GDP)(transition) Europe  0.144864
#
# Year                                                                    2042  \
# Scenario           Variable                                 Region
# Delayed transition Gross Domestic Product (GDP)(transition) Europe -0.745747
# Net Zero 2050      Gross Domestic Product (GDP)(transition) Europe  0.169195
#
# Year                                                                    2043  \
# Scenario           Variable                                 Region
# Delayed transition Gross Domestic Product (GDP)(transition) Europe -0.788750
# Net Zero 2050      Gross Domestic Product (GDP)(transition) Europe  0.193125
#
# Year                                                                    2044  \
# Scenario           Variable                                 Region
# Delayed transition Gross Domestic Product (GDP)(transition) Europe -0.834480
# Net Zero 2050      Gross Domestic Product (GDP)(transition) Europe  0.218519
#
# Year                                                                    2045  \
# Scenario           Variable                                 Region
# Delayed transition Gross Domestic Product (GDP)(transition) Europe -0.884500
# Net Zero 2050      Gross Domestic Product (GDP)(transition) Europe  0.246833
#
# Year                                                                    2046  \
# Scenario           Variable                                 Region
# Delayed transition Gross Domestic Product (GDP)(transition) Europe -0.931998
# Net Zero 2050      Gross Domestic Product (GDP)(transition) Europe  0.256492
#
# Year                                                                    2047  \
# Scenario           Variable                                 Region
# Delayed transition Gross Domestic Product (GDP)(transition) Europe -0.969640
# Net Zero 2050      Gross Domestic Product (GDP)(transition) Europe  0.252234
#
# Year                                                                    2048  \
# Scenario           Variable                                 Region
# Delayed transition Gross Domestic Product (GDP)(transition) Europe -0.998323
# Net Zero 2050      Gross Domestic Product (GDP)(transition) Europe  0.247595
#
# Year                                                                    2049  \
# Scenario           Variable                                 Region
# Delayed transition Gross Domestic Product (GDP)(transition) Europe -1.016418
# Net Zero 2050      Gross Domestic Product (GDP)(transition) Europe  0.241775
#
# Year                                                                    2050
# Scenario           Variable                                 Region
# Delayed transition Gross Domestic Product (GDP)(transition) Europe -1.020630
# Net Zero 2050      Gross Domestic Product (GDP)(transition) Europe  0.234063
#
# [2 rows x 29 columns]

# %%
print(remind_pivot.columns)  # Should be like Ints: 2020, 2025, ...
print(nigem_pivot.columns)
# Out:
# Index([2020, 2025, 2030, 2035, 2040, 2045, 2050, 2055, 2060, 2065, 2070, 2075,
#        2080, 2085, 2090, 2095, 2100],
#       dtype='int64', name='Year')
# Index([2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033,
#        2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044, 2045,
#        2046, 2047, 2048, 2049, 2050],
#       dtype='int64', name='Year')

# %%
common_years = remind_pivot.columns.intersection(nigem_pivot.columns)

# %%
common_years
# Out:
# Index([2025, 2030, 2035, 2040, 2045, 2050], dtype='int64', name='Year')

# %%
# Parameters
beta_macro = 0.5
beta_carbon = 0.3
PD_base = 0.02

# Calculate PDs
results = []

# %%
for scenario in scenarios:
        for year in common_years:
            try:
                carbon_price = remind_pivot.loc[(scenario, 'Price|Carbon', 'EU27'), year]
                gdp = nigem_pivot.loc[(scenario, 'Gross Domestic Product (GDP)(transition)', 'Europe'), year]
                emissions = remind_pivot.loc[(scenario, 'Emissions|CO2|Energy', 'EU27'), year]
                gdp_shock = (gdp - 100) / 100  # assume baseline is 100
                carbon_shock = (carbon_price - 50) / 50  # assume baseline 50
                pd_base = 0.02
                beta_macro = 3
                beta_carbon = 1.5
                pd_new = pd_base * (1 + beta_macro * gdp_shock + beta_carbon * carbon_shock)
                results.append({'Scenario': scenario, 'Year': year, 'PD_new': pd_new})
            except KeyError:
                print(f"Missing data for {scenario}, {year}")
                continue

# %%
# Create DataFrame and plot
results_df = pd.DataFrame(results)

# %%
results_df.columns
# Out:
# Index(['Scenario', 'Year', 'PD_new'], dtype='object')

# %%
for scenario in scenarios:
    df_scen = results_df[results_df['Scenario'] == scenario]
    plt.plot(df_scen['Year'], df_scen['PD_new'], label=scenario)

plt.title('Projected PD under Climate Scenarios')
plt.xlabel('Year')
plt.ylabel('Probability of Default (PD)')
plt.legend()
plt.grid(True)
plt.show()
